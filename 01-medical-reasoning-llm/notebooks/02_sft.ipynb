# %% [markdown]
# <a href="https://colab.research.google.com/github/xueqingnie/ml-ai-portfolio/blob/main/01-medical-reasoning-llm/notebooks/02_sft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Medical Reasoning LLM — SFT

# %%
# %cd /content/ml-ai-portfolio
# Out:
# [Errno 2] No such file or directory: '/content/ml-ai-portfolio'
# /content

# %%
import pandas as pd

train = pd.read_csv("../datasets/processed/train_clean.csv")

print(train.shape)
print(train.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_771/3295241631.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 train = pd.read_csv("../datasets/processed/train_clean.csv")
#       4
#       5 print(train.shape)
#
# ...

# %%
# !ls
# Out:
# sample_data
